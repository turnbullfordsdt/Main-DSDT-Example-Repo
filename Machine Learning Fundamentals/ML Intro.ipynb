# %%
from pandas import read_csv

dataset = read_csv("/workspaces/Main-DSDT-Example-Repo/Machine Learning Fundamentals/kc_house_cleaned (2).csv")

# %%
display(dataset)
# Out:
#        Unnamed: 0     price  ...  roof_type_Metal  waterfront
# 0               0  221900.0  ...            False       False
# 1               2  180000.0  ...             True       False
# 2               3  604000.0  ...            False       False
# 3               4  510000.0  ...            False       False
# 4               5  510000.0  ...            False       False
# ...           ...       ...  ...              ...         ...
# 18750       18764  400000.0  ...            False       False
# 18751       18765  529941.0  ...             True       False
# 18752       18766  310000.0  ...            False       False
# 18753       18767  389000.0  ...            False       False
# 18754       18768  731781.0  ...             True       False
#
# [18755 rows x 23 columns]

# %%
target_column_name = 'price'

# %%
target_column  = dataset['price']

display(target_column)
# Out:
# 0        221900.0
# 1        180000.0
# 2        604000.0
# 3        510000.0
# 4        510000.0
#            ...
# 18750    400000.0
# 18751    529941.0
# 18752    310000.0
# 18753    389000.0
# 18754    731781.0
# Name: price, Length: 18755, dtype: float64

# %%
input_set = dataset.drop(columns=['price', 'Unnamed: 0'])

display(input_set)
# Out:
#        bedrooms  bathrooms  ...  roof_type_Metal  waterfront
# 0             3        1.0  ...            False       False
# 1             2        1.0  ...             True       False
# 2             4        3.0  ...            False       False
# 3             3        2.0  ...            False       False
# 4             3        2.0  ...            False       False
# ...         ...        ...  ...              ...         ...
# 18750         3        2.5  ...            False       False
# 18751         3        2.0  ...             True       False
# 18752         3        1.0  ...            False       False
# 18753         3        1.0  ...            False       False
# 18754         3        3.0  ...             True       False
#
# [18755 rows x 21 columns]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(input_set, target_column)
# Out:
# LinearRegression()

# %%
predictions = model.predict(input_set)

# %%
from sklearn.metrics import mean_squared_error

loss = mean_squared_error(target_column, predictions)

# %%
loss
# Out:
# 42761043897.189644

# %%
import math

math.sqrt(loss)
# Out:
# 206787.43650712835

# %%
(prediction - actual)
